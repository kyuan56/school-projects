# %% [markdown]
# ## Presentation Demo

# %%
from AOF_Ske_Pkg import medial_axis

# %%
import matplotlib.pyplot as plt

# %%
img_path = "data/horse.png"
flux_Image,distance_Image,skeleton_Image=medial_axis(img_path,0.3,"interior")

# %%
plt.imshow(distance_Image)

# %%
plt.imshow(flux_Image)

# %%
plt.imshow(skeleton_Image)

# %%
flux_Image,distance_Image,skeleton_Image=medial_axis(img_path,0.3,"exterior")

# %%
plt.imshow(distance_Image)

# %%
plt.imshow(flux_Image)

# %%
plt.imshow(skeleton_Image)

# %%
flux_Image,distance_Image,skeleton_Image=medial_axis(img_path,0.3,"full")

# %%
plt.imshow(distance_Image)

# %%
plt.imshow(flux_Image)

# %%
plt.imshow(skeleton_Image)
